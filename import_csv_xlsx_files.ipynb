# %%
import pandas as pd

# %%
new=pd.read_csv(r"C:\Users\Admin\Desktop\PYTHON\insurance.csv")
new
# Out:
#       age     sex     bmi  children smoker region      charges      Month
# 0      19  female  27.900         0    yes  South  16884.92400  16.884924
# 1      18    male  33.770         1     no  South   1725.55230   1.725552
# 2      28    male  33.000         3     no  South   4449.46200   4.449462
# 3      33    male  22.705         0     no  North  21984.47061  21.984471
# 4      32    male  28.880         0     no  North   3866.85520   3.866855
# ...   ...     ...     ...       ...    ...    ...          ...        ...
# 1333   50    male  30.970         3     no  North  10600.54830  10.600548
# 1334   18  female  31.920         0     no  North   2205.98080   2.205981
# 1335   18  female  36.850         0     no  South   1629.83350   1.629833
# 1336   21  female  25.800         0     no  South   2007.94500   2.007945
# 1337   61  female  29.070         0    yes  North  29141.36030  29.141360
#
# [1338 rows x 8 columns]

# %%
new_2=pd.read_excel(r"C:\Users\Admin\Desktop\PYTHON\myworkbook.xlsx")
new_2
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
new_3=pd.read_excel(r"C:\Users\Admin\Desktop\PYTHON\myworkbook.xlsx",sheet_name="faithful")
new_3
# Out:
#      eruptions  waiting
# 0        3.600       79
# 1        1.800       54
# 2        3.333       74
# 3        2.283       62
# 4        4.533       85
# ..         ...      ...
# 267      4.117       81
# 268      2.150       46
# 269      4.417       90
# 270      1.817       46
# 271      4.467       74
#
# [272 rows x 2 columns]

# %%
new_2.to_csv(r"C:\Users\Admin\Desktop\PYTHON\demo.csv",index=False)

# %%
new_2=pd.read_csv(r"C:\Users\Admin\Desktop\PYTHON\demo.csv")
new_2
# Out:
#     Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0            0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1            1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2            2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3            3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4            4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5            5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6            6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7            7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8            8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9            9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10          10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# ...

# %%
new.to_excel(r"C:\Users\Admin\Desktop\PYTHON\demo2.xlsx",index="False")

# %%
new=pd.read_excel(r"C:\Users\Admin\Desktop\PYTHON\demo2.xlsx")
new
# Out:
#     Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0            0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1            1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2            2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3            3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4            4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5            5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6            6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7            7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8            8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9            9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10          10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# ...
