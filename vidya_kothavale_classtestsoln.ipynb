# %%
import pandas as pd

# %% [markdown]
# # Q1.

# %%
df=pd.read_excel(r"Global_Superstore.xlsx" )
df
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df1=pd.read_excel(r"Global_Superstore.xlsx" ,sheet_name='Orders')
df1
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df2=pd.read_excel(r"Global_Superstore.xlsx" ,sheet_name='Return')
df2
# Out:
#                       Order_ID Returned           Region
# 0     CA-2012-SA20830140-41210      Yes       Central US
# 1     IN-2012-PB19210127-41259      Yes     Eastern Asia
# 2     CA-2012-SC20095140-41174      Yes       Central US
# 3       IN-2015-JH158207-42140      Yes          Oceania
# 4       IN-2014-LC168857-41747      Yes          Oceania
# ...                        ...      ...              ...
# 1074   IN-2014-DA1345058-41769      Yes    Southern Asia
# 1075  US-2013-HG14845140-41530      Yes       Eastern US
# 1076   US-2013-SJ2021582-41543      Yes  Central America
# 1077  CA-2015-EB13870140-42269      Yes       Eastern US
# 1078    EG-2014-PM894038-41846      Yes     North Africa
#
# [1079 rows x 3 columns]

# %% [markdown]
# # Q2.

# %%
pd.merge(df1,df2 , on='Order_ID',how='inner')
# Out:
#       Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 1      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   35040  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2216   35038  CA-2014-WB21850140-41654 2014-01-15 2014-01-21  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36974  CA-2012-ZC21910140-41271 2012-12-28 2013-01-04  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
# ...

# %%
pd.merge(df1,df2 ,on='Order_ID',how='outer')
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 3       26339    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 4       26340    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
pd.merge(df1,df2 ,on='Order_ID',how='left')
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
pd.merge(df1,df2 ,on='Order_ID',how='right')
# Out:
#       Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0      31784  CA-2012-SA20830140-41210 2012-10-28 2012-10-30     First Class
# 1      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 2      30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 3      30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 4      30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# ...      ...                       ...        ...        ...             ...
# 2215   28736   IN-2014-DA1345058-41769 2014-05-10 2014-05-15  Standard Class
# 2216   37649  US-2013-HG14845140-41530 2013-09-13 2013-09-19  Standard Class
# 2217      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29     First Class
# 2218   36053  CA-2015-EB13870140-42269 2015-09-22 2015-09-26  Standard Class
# 2219   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
#
# ...

# %% [markdown]
# # Q3.

# %%
df=pd.read_excel(r"Global_Superstore.xlsx" ,index_col='Row ID')
df
# Out:
#                         Order_ID Order Date  Ship Date       Ship Mode  \
# Row ID
# 40098   CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 26341     IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 25330     IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 13524    ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 47221    SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                          ...        ...        ...             ...
# 29002    IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 34337   US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 31315   CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 9596     MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 6147     MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#          Customer ID       Customer Name      Segment  Postal Code  \
# Row ID
# ...

# %%
#3.question

df.iloc[1:10,1:5]
# Out:
#                          Order Date  Ship Date       Ship Mode   Customer ID
# Order_ID
# IN-2014-JR162107-41675   2014-02-05 2014-02-07    Second Class     JR-162107
# IN-2014-CR127307-41929   2014-10-17 2014-10-18     First Class     CR-127307
# ES-2014-KM1637548-41667  2014-01-28 2014-01-30     First Class    KM-1637548
# SG-2014-RH9495111-41948  2014-11-05 2014-11-06        Same Day    RH-9495111
# IN-2014-JM156557-41818   2014-06-28 2014-07-01    Second Class     JM-156557
# IN-2012-TS2134092-41219  2012-11-06 2012-11-08     First Class    TS-2134092
# IN-2013-MB1808592-41378  2013-04-14 2013-04-18  Standard Class    MB-1808592
# CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class  AB-100151402
# CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class  AB-100151404

# %%
df.loc[1:10,"City":"Product_Name"]
# Out:
#              City            State        Country          Region  \
# 1      Wollongong  New South Wales      Australia         Oceania
# 2        Brisbane       Queensland      Australia         Oceania
# 3          Berlin           Berlin        Germany  Western Europe
# 4           Dakar            Dakar        Senegal  Western Africa
# 5          Sydney  New South Wales      Australia         Oceania
# 6         Porirua       Wellington    New Zealand         Oceania
# 7        Hamilton          Waikato    New Zealand         Oceania
# 8   Oklahoma City         Oklahoma  United States      Central US
# 9         Seattle       Washington  United States      Western US
# 10        Seattle       Washington  United States      Western US
#
#           Market   Product_ID         Category Sub_Category  \
# 1   Asia Pacific  FUR-CH-5379        Furniture       Chairs
# 2   Asia Pacific  TEC-PH-5356       Technology       Phones
# ...

# %% [markdown]
# # Q4.

# %%
#4th uestion
df.loc[df.Profit > 0,:]
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# # Q6.

# %%
#6.
x=10
y=20
print(type(x))
print(type(y))
x1=float(x)
y1=float(y)
print(type(x1))
print(type(y1))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# # Q5

# %%
#5.

Sales=100
Revenue=Sales

print(Revenue)
# Out:
# 100
