# %%
import pandas as pd

# %%
import numpy as np

# %%
d={
    'Name':['Allisha','Bobby','Cathrine','Madonna','Rocky','Sebastian','jaqluine','rahul',
    'David','Andrew','Ajay','Teresa'],
    'Age':[36,27,25,24,31,27,25,33,42,32,51,47],
    'Score':[89,87,67,55,47,72,76,79,44,99,92,99]
}
df=pd.DataFrame(d)
df
# Out:
#          Name  Age  Score
# 0     Allisha   36     89
# 1       Bobby   27     87
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 4       Rocky   31     47
# 5   Sebastian   27     72
# 6    jaqluine   25     76
# 7       rahul   33     79
# 8       David   42     44
# 9      Andrew   32     99
# 10       Ajay   51     92
# 11     Teresa   47     99

# %%
df.sort_values(by='Score')
# Out:
#          Name  Age  Score
# 8       David   42     44
# 4       Rocky   31     47
# 3     Madonna   24     55
# 2    Cathrine   25     67
# 5   Sebastian   27     72
# 6    jaqluine   25     76
# 7       rahul   33     79
# 1       Bobby   27     87
# 0     Allisha   36     89
# 10       Ajay   51     92
# 9      Andrew   32     99
# 11     Teresa   47     99

# %%
df.sort_values(by='Score',ascending=False)
# Out:
#          Name  Age  Score
# 9      Andrew   32     99
# 11     Teresa   47     99
# 10       Ajay   51     92
# 0     Allisha   36     89
# 1       Bobby   27     87
# 7       rahul   33     79
# 6    jaqluine   25     76
# 5   Sebastian   27     72
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 4       Rocky   31     47
# 8       David   42     44

# %%
df1=df.sort_index()
df1
# Out:
#          Name  Age  Score
# 0     Allisha   36     89
# 1       Bobby   27     87
# 2    Cathrine   25     67
# 3     Madonna   24     55
# 4       Rocky   31     47
# 5   Sebastian   27     72
# 6    jaqluine   25     76
# 7       rahul   33     79
# 8       David   42     44
# 9      Andrew   32     99
# 10       Ajay   51     92
# 11     Teresa   47     99

# %%
df2=df.sort_index(ascending=False)
df2
# Out:
#          Name  Age  Score
# 11     Teresa   47     99
# 10       Ajay   51     92
# 9      Andrew   32     99
# 8       David   42     44
# 7       rahul   33     79
# 6    jaqluine   25     76
# 5   Sebastian   27     72
# 4       Rocky   31     47
# 3     Madonna   24     55
# 2    Cathrine   25     67
# 1       Bobby   27     87
# 0     Allisha   36     89

# %%
df.head()
# Out:
#        Name  Age  Score
# 0   Allisha   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
df.drop('Age',axis=1)
# Out:
#          Name  Score
# 0     Allisha     89
# 1       Bobby     87
# 2    Cathrine     67
# 3     Madonna     55
# 4       Rocky     47
# 5   Sebastian     72
# 6    jaqluine     76
# 7       rahul     79
# 8       David     44
# 9      Andrew     99
# 10       Ajay     92
# 11     Teresa     99

# %%
df.head()
# Out:
#        Name  Age  Score
# 0   Allisha   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
df.drop(['Age','Score'],axis=1)
# Out:
#          Name
# 0     Allisha
# 1       Bobby
# 2    Cathrine
# 3     Madonna
# 4       Rocky
# 5   Sebastian
# 6    jaqluine
# 7       rahul
# 8       David
# 9      Andrew
# 10       Ajay
# 11     Teresa

# %%
df.head()
# Out:
#        Name  Age  Score
# 0   Allisha   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
df.drop(df.columns[1],axis=1)
# Out:
#          Name  Score
# 0     Allisha     89
# 1       Bobby     87
# 2    Cathrine     67
# 3     Madonna     55
# 4       Rocky     47
# 5   Sebastian     72
# 6    jaqluine     76
# 7       rahul     79
# 8       David     44
# 9      Andrew     99
# 10       Ajay     92
# 11     Teresa     99

# %%
df=df.drop(2,axis=0)
df
# Out:
#          Name  Age  Score
# 0     Allisha   36     89
# 1       Bobby   27     87
# 3     Madonna   24     55
# 4       Rocky   31     47
# 5   Sebastian   27     72
# 6    jaqluine   25     76
# 7       rahul   33     79
# 8       David   42     44
# 9      Andrew   32     99
# 10       Ajay   51     92
# 11     Teresa   47     99

# %%
del df['Age']
df
# Out:
#          Name  Score
# 0     Allisha     89
# 1       Bobby     87
# 3     Madonna     55
# 4       Rocky     47
# 5   Sebastian     72
# 6    jaqluine     76
# 7       rahul     79
# 8       David     44
# 9      Andrew     99
# 10       Ajay     92
# 11     Teresa     99

# %%
import numpy as np
d={
    'Name':['Alisha','Bobby','jodha','jack','raghu','Cathrine','Alisha','Bobby','kumar',
            'Alisha','Alex','Cathrine'],
    'Age':[36,24,23,22,23,24,26,24,22,23,24,24],
    'Score':[85,63,55,74,31,77,85,63,42,62,89,77]
}

df=pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0     Alisha   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6     Alisha   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9     Alisha   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %%
df["check_duplicate"] = df.duplicated()
df
# Out:
#         Name  Age  Score  check_duplicate
# 0     Alisha   36     85            False
# 1      Bobby   24     63            False
# 2      jodha   23     55            False
# 3       jack   22     74            False
# 4      raghu   23     31            False
# 5   Cathrine   24     77            False
# 6     Alisha   26     85            False
# 7      Bobby   24     63             True
# 8      kumar   22     42            False
# 9     Alisha   23     62            False
# 10      Alex   24     89            False
# 11  Cathrine   24     77             True

# %%
d={
    'Name':['Alisha','Bobby','jodha','jack','raghu','Cathrine','Alisha','Bobby','kumar',
            'Alisha','Alex','Cathrine'],
    'Age':[36,24,23,22,23,24,26,24,22,23,24,24],
    'Score':[85,63,55,74,31,77,85,63,42,62,89,77]
}

df=pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0     Alisha   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6     Alisha   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9     Alisha   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %%
df.drop_duplicates()
# Out:
#         Name  Age  Score
# 0     Alisha   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6     Alisha   26     85
# 8      kumar   22     42
# 9     Alisha   23     62
# 10      Alex   24     89

# %%
df.drop_duplicates(keep='last')
# Out:
#         Name  Age  Score
# 0     Alisha   36     85
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 6     Alisha   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9     Alisha   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %%
#by col
d={
    'Name':['Alisha','Bobby','jodha','jack','raghu','Cathrine','Alisha','Bobby','kumar',
            'Alisha','Alex','Cathrine'],
    'Age':[36,24,23,22,23,24,26,24,22,23,24,24],
    'Score':[85,63,55,74,31,77,85,63,42,62,89,77]
}

df=pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0     Alisha   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6     Alisha   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9     Alisha   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %%
df.drop_duplictes([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 df.drop_duplictes([])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplictes'
